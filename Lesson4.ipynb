# %% [markdown]
# 1.Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# %%
a = 200
b = 800
M = (a + b) / 2
print(f'Среднее значение случайной непрерывной величины А на промежутке равно: {M}')
D = (b - a) ** 2 / 12
print(f'Дисперсия случайно величины А на промежутке равна: {D}')
# Out:
# Среднее значение случайной непрерывной величины А на промежутке равно: 500.0
# Дисперсия случайно величины А на промежутке равна: 30000.0

# %% [markdown]
# 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.

# %%
from math import sqrt
D = 0.2
a = 0.5
b = sqrt(12 * D) + a
print(f'Правая граница величины В равна: {b}')
M = (a + b) / 2
print(f'Среднее значение величины: {M}')
# Out:
# Правая граница величины В равна: 2.049193338482967
# Среднее значение величины: 1.2745966692414834

# %% [markdown]
# 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения
# f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-((x+2)**2) / 32))
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)

# %%
M(X) = -2
D(X) = 16
std(x) = 4

# %% [markdown]
# 4. Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.

# %%
std(X) = 8
M = 174

# %% [markdown]
# а) Вероятность того, что человек имеет рост больше 182 (+1 сигма) см равна: 1 - 0,8413 = 0,1587
# б) Вероятность того, что человек имеет рост больше 190 (+2 сигмы) см равна: 1 - 0,9772 = 0,0228
# в) Вероятность того, что человек имеет рост от 166 до 190 (от -1 до +2 сигм)см равна: 0,9772 - (1 - 0,8413) = 0,8185
# г) Вероятность того, что человек имеет рост от 166 до 182 (от -1 до +1 сигмы)см равна: 0,8413 - 0,1587 = 0,6826
# д) Вероятность того, что человек имеет рост от 158 до 190 (от -2 до +2 сигм)см равна: 0,9772 - 0,0228 = 0,9544
# е) Вероятность того, что человек имеет рост не выше 150 см или не ниже 190 см: 0,0013 + 0,0228 = 0,0241
# ё) Вероятность того, что человек имеет рост не выше 150 см или не ниже 198 см: 0,0013 + 0,0013 = 0,0026
# ж) Вероятность того, что человек имеет рост ниже 166 см: 0,1587

# %% [markdown]
# 5. На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %%
D = 25
M = 178
L = 190
print(f'Рост человека отклоняется от мат.ожидания роста в популяции на {(L - M) / sqrt(D)} сигм')
# Out:
# Рост человека отклоняется от мат.ожидания роста в популяции на 2.4 сигм
